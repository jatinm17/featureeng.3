# %%
# QUES 1
print("MinMax Scaler shrinks the data within the given range, usually of 0 to 1. It transforms data by scaling features to a given range. It scales the values to a specific value range without changing the shape of the original distribution.")

from sklearn.preprocessing import StandardScaler

# create data
data = [[11, 2], [3, 7], [0, 10], [11, 8]]

scaler = StandardScaler()
model = scaler.fit(data)
scaled_data = model.transform(data)

# print scaled data
print(scaled_data)
# Out:
# MinMax Scaler shrinks the data within the given range, usually of 0 to 1. It transforms data by scaling features to a given range. It scales the values to a specific value range without changing the shape of the original distribution.
# [[ 0.97596444 -1.61155897]
#  [-0.66776515  0.08481889]
#  [-1.28416374  1.10264561]
#  [ 0.97596444  0.42409446]]

# %%
# QUES 2
print("Like Min-Max Scaling, the Unit Vector technique produces values of range [0,1]. When dealing with features with hard boundaries, this is quite useful. For example, when dealing with image data, the colors can range from only 0 to 255.")
# Out:
# Like Min-Max Scaling, the Unit Vector technique produces values of range [0,1]. When dealing with features with hard boundaries, this is quite useful. For example, when dealing with image data, the colors can range from only 0 to 255.

# %%
# QUES 3
print("Principal component analysis, or PCA, is a dimensionality reduction method that is often used to reduce the dimensionality of large data sets, by transforming a large set of variables into a smaller one that still contains most of the information in the large set.")
print('''PCA is mainly used as the dimensionality reduction technique in various AI applications such as computer vision, image compression, etc.
It can also be used for finding hidden patterns if data has high dimensions. Some fields where PCA is used are Finance, data mining, Psychology, etc.
''')
# Out:
# Principal component analysis, or PCA, is a dimensionality reduction method that is often used to reduce the dimensionality of large data sets, by transforming a large set of variables into a smaller one that still contains most of the information in the large set.
# PCA is mainly used as the dimensionality reduction technique in various AI applications such as computer vision, image compression, etc.
# It can also be used for finding hidden patterns if data has high dimensions. Some fields where PCA is used are Finance, data mining, Psychology, etc.

# %%
# QUESTION 4
print("PCA can be used to identify the most important features in a dataset, which can be used to build predictive models. Visualization: PCA can be used to visualize high-dimensional data in two or three dimensions, making it easier to understand and interpret.")
# Out:
# PCA can be used to identify the most important features in a dataset, which can be used to build predictive models. Visualization: PCA can be used to visualize high-dimensional data in two or three dimensions, making it easier to understand and interpret.

# %%
# QUESTION 5
from sklearn.preprocessing import MinMaxScaler

# Assuming 'data' is your dataset with columns: price, rating, delivery_time
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data[['price', 'rating', 'delivery_time']]
# Out:
#   Cell In[7], line 6
#     scaled_data = scaler.fit_transform(data[['price', 'rating', 'delivery_time']]
#                                                                                  ^
# SyntaxError: incomplete input

# %%
# QUESTION 6
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.datasets import make_regression

# Generate some sample data (replace this with your actual dataset)
n_samples, n_features = 100, 20
X, y = make_regression(n_samples=n_samples, n_features=n_features, noise=0.1)


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 2: Apply PCA
n_components = 10  
pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X_scaled)

# Explained variance ratio by each component
explained_variance_ratio = pca.explained_variance_ratio_

# Print explained variance ratio for each component
print("Explained Variance Ratio:", explained_variance_ratio)


X_reconstructed = pca.inverse_transform(X_pca)

# Print the shape of the reduced and reconstructed data
print("Reduced Dimension Data Shape:", X_pca.shape)
print("Reconstructed Data Shape:", X_reconstructed.shape)
# Out:
# Explained Variance Ratio: [0.09721035 0.0840076  0.0742209  0.06964476 0.06561229 0.06271357
#  0.05771202 0.05584107 0.05461686 0.05014056]
# Reduced Dimension Data Shape: (100, 10)
# Reconstructed Data Shape: (100, 20)

# %%
# QUESTION 7
from sklearn.preprocessing import MinMaxScaler


scaler = MinMaxScaler()
data=[[1,5,10,15,20]]
scaled_data = scaler.fit_transform(data)
scaled_data
# Out:
# array([[0., 0., 0., 0., 0.]])

# %%
# QUESTION 8
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Sample data (replace this with your actual dataset)
data = {
    'height': [170, 165, 180, 155, 175],
    'weight': [70, 60, 85, 50, 65],
    'age': [30, 25, 40, 22, 28],
    'gender': [1, 0, 1, 0, 1],
    'blood_pressure': [120, 110, 130, 100, 125]
}

df = pd.DataFrame(data)

# Extract features and standardize the data
X = df.drop(columns=['gender'])  # Exclude non-numeric feature
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply PCA
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# Calculate explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_explained_variance = np.cumsum(explained_variance_ratio)

# Plot cumulative explained variance
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, marker='o')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance vs. Number of Principal Components')
plt.grid(True)
plt.show()

# Determine number of principal components to retain based on a threshold (e.g., 95%)
threshold = 0.95
num_components_to_retain = np.argmax(cumulative_explained_variance >= threshold) + 1

print("Number of Principal Components to Retain:", num_components_to_retain)
# Out:
# Number of Principal Components to Retain: 2
